# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("HR.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales  salary
# 0                          0    sales     low
# 1                          0    sales  medium
# 2                          0    sales  medium
# 3                          0    sales     low
# 4                          0    sales     low
# ...                      ...      ...     ...
# 14994                      0  support     low
# 14995                      0  support     low
# 14996                      0  support     low
# 14997                      0  support     low
# 14998                      0  support     low
#
# [14999 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.title("SALARY")
plt.xlabel("salary")
plt.ylabel("Number")
plt.xticks(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts().index)
plt.bar(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts(),width=0.5)
for x,y in zip(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts()):
    plt.text(x,y,y,ha="center",va="bottom")
plt.show()

# %%
## 接下来我们来展示一下seaborn的用法
sns.set_style(style="darkgrid")
plt.title("SALARY")
plt.xlabel("salary")
plt.ylabel("Number")
plt.xticks(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts().index)
plt.bar(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts(),width=0.5)
for x,y in zip(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts()):
    plt.text(x,y,y,ha="center",va="bottom")
plt.show()

# %%
sns.set_style(style="whitegrid")
sns.set_context(context="paper",font_scale= 0.5)
sns.set_palette("Reds")
plt.title("SALARY")
plt.xlabel("salary")
plt.ylabel("Number")
plt.xticks(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts().index)
plt.bar(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts(),width=0.5)
for x,y in zip(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts()):
    plt.text(x,y,y,ha="center",va="bottom")
plt.show()

# %%
## 我们可以直接设置
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("HR.csv")
sns.set_style(style="whitegrid")
sns.set_context(context="poster",font_scale= 0.8)
sns.set_palette(sns.color_palette("RdBu",n_colors=6))
# sns.countplot(x="salary",hue="department",data=df)
plt.title("SALARY")
plt.xlabel("salary")
plt.ylabel("Number")
plt.xticks(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts().index)
plt.bar(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts(),width=0.5)
for x,y in zip(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts()):
    plt.text(x,y,y,ha="center",va="bottom")
plt.show()

# %%
## 我们可以直接设置,因为sns是matplotlib的一个分装
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("HR.csv")
sns.set_style(style="whitegrid")
sns.set_context(context="poster",font_scale= 0.8)
sns.set_palette(sns.color_palette("RdBu",n_colors=6))
sns.countplot(x="salary",hue="sales",data=df)
# plt.title("SALARY")
# plt.xlabel("salary")
# plt.ylabel("Number")
# plt.xticks(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts().index)
# plt.bar(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts(),width=0.5)
# for x,y in zip(np.arange(len(df["salary"].value_counts())),df["salary"].value_counts()):
#     plt.text(x,y,y,ha="center",va="bottom")
# plt.show()
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# ste_style一共有这么多种备选值，darkgrid,whitegrid,dark,white,ticks
# 当然我们也可以设置字体set_context,有paper,notebook,talk,poster,
# 同样我们可以设置字体颜色，set_palette，颜色可以在网上查询
